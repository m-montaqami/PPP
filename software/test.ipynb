# %% [markdown]
# ##

# %%
run main.py

# %%
#ECEF
from matplotlib import pyplot as plt
x=[i[0] for i in process1.processed]
y=[i[1] for i in process1.processed]
z=[i[2] for i in process1.processed]
ZWD=[i[3] for i in process1.processed]
clk=[i[4]*1e+9/C for i in process1.processed]
# isb=[i[5] for i in process1.processed]
plt.plot(clk[10:])
print(x[-1])
print(y[-1])
print(z[-1])
# Out:
# [3995225.81556855]
# [1384965.70908464]
# [4759432.65688851]

# %%
x_res=[i[0] for i in process1.residual][10:]
y_res=[i[1] for i in process1.residual][10:]
z_res=[i[2] for i in process1.residual][10:]
zwd_res=[i[4] for i in process1.residual]
plt.plot(x_res[0:],'r');plt.plot(y_res[0:],'b');plt.plot(z_res[0:],'g')
# plt.plot(zwd_res)

# %%
plt.plot([i[0,:] for i in process1.Ns],'.')
# plt.plot([i[0,:] for i in process1.W_X_Ns],'.')
